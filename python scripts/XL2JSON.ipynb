# %%
import pandas as pd
import json


df = pd.read_excel(r"C:\Users\G278440\OneDrive - PPG Industries, Inc\Desktop\Excel Files\RITSD_Escalation_Contacts.xlsx")

df.columns = df.iloc[0]

df = df.iloc[1:]

#df.to_csv("../contacts.csv", encoding='utf-8')

result = df.to_json(orient="index")
parsed = json.loads(result)
json.dumps(parsed, indent=6)

print(parsed)

with open('../contacts.json', 'w') as f:
    json.dump(parsed, f)
# Out:
# {'1': {'Entity:': 'Apex (US) & Apex (CA)', 'Phone:': None, 'Email:': 'afstorespricing@ppg.com\xa0\xa0 \xa0CanadaStorespricing@ppg.com', 'Individual:': None}, '2': {'Entity:': 'Bell Alliance', 'Phone:': '888-214-7896', 'Email:': None, 'Individual:': None}, '3': {'Entity:': 'Bell Canada', 'Phone:': '877-877-2426', 'Email:': '888-788-2355  or 866-462-3551', 'Individual:': None}, '4': {'Entity:': 'Cash Desk (US)', 'Phone:': None, 'Email:': 'PPGACCashDesk@ppg.com', 'Individual:': None}, '5': {'Entity:': 'Cash Desk (CA)', 'Phone:': None, 'Email:': 'CanadaBankingSupport@ppg.com', 'Individual:': None}, '6': {'Entity:': 'CEI Driver Services', 'Phone:': '866.894.0383', 'Email:': 'driverservices.PPG@ceinetwork.com', 'Individual:': None}, '7': {'Entity:': 'Color Lab', 'Phone:': '412-517-3738', 'Email:': 'accolorlab@ppg.com', 'Individual:': None}, '8': {'Entity:': 'Corob Service', 'Phone:': '800-728-8408', 'Email:': 'ext. 225  -- Previously Listed as 255', 'Individual:': 'Tech: Mike'}, '9': {'Ent
# ...

# %%
import pandas as pd
import json

df = pd.read_excel(r"C:\Users\G278440\OneDrive - PPG Industries, Inc\Desktop\Excel Files\passwords.xlsx")

df.columns = df.iloc[0]
df = df.iloc[1:]

df.to_csv("../passwords.csv", encoding='utf-8')

result = df.to_json(orient="index")
parsed = json.loads(result)
json.dumps(parsed, indent=6)

print(parsed)

with open('../passwords.json', 'w') as f:
    json.dump(parsed, f)
# Out:
# {'1': {'Description': 'PltadminPAF', 'Account': '.\\pltadmin', 'Password': 'Use PPG Password Manager Tool', 'Added by': 'Kathleen Montefiori', 'Date': 1592265600000, 'nan': None}, '2': {'Description': 'Netgate Admin Login', 'Account': None, 'Password': 'PPGanira08', 'Added by': 'Josh Schwartz', 'Date': 1437264000000, 'nan': None}, '3': {'Description': 'PAFSD', 'Account': 'PAFSD', 'Password': 'V1ning1vy2025', 'Added by': 'Justin Wilt', 'Date': 1692057600000, 'nan': None}, '4': {'Description': 'Fortinet Voicemail', 'Account': None, 'Password': 123123, 'Added by': 'Kathleen Montefiori', 'Date': 1525824000000, 'nan': None}, '5': {'Description': 'Fortinet IP Phones', 'Account': 'admin', 'Password': 23646, 'Added by': 'Josh Schwartz', 'Date': 1445472000000, 'nan': None}, '6': {'Description': 'PRTG', 'Account': 'acstores', 'Password': 'ACstores2015', 'Added by': 'Kevin Swantner', 'Date': 1449100800000, 'nan': None}, '7': {'Description': 'PRTG - CA', 'Account': 'cappgc User ID: cappgc01', 'P
# ...
